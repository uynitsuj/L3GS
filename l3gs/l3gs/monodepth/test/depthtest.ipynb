# %%
from l3gs.monodepth.litemono_network import LiteMonoNetwork, LiteMonoNetworkConfig
import PIL.Image as pil
import os
import time
import matplotlib.pyplot as plt
import glob

depth_model = LiteMonoNetwork(LiteMonoNetworkConfig)
for filename in glob.glob(os.path.join('testimages','*.jpg')):
    image = pil.open(os.path.join('.', filename)).convert('RGB')
    plt.imshow(image)
    plt.show()
    start = time.time()
    depth_model.get_depth(image)
    end = time.time()
    print(f'Inference time: {end - start} seconds')
# Out:
# Inference time: 0.4687471389770508 seconds
# Inference time: 0.6593959331512451 seconds
# Inference time: 0.2990531921386719 seconds
# Inference time: 0.12766766548156738 seconds
