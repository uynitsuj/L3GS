# %%
from l3gos.monodepth.litemono_network import LiteMonoNetwork, LiteMonoNetworkConfig
import PIL.Image as pil
import os
import time
import matplotlib.pyplot as plt
import glob

depth_model = LiteMonoNetwork(LiteMonoNetworkConfig)
for filename in glob.glob(os.path.join('testimages','*.jpg')):
    image = pil.open(os.path.join('.', filename)).convert('RGB')
    plt.imshow(image)
    plt.show()
    start = time.time()
    depth_model.get_depth(image)
    end = time.time()
    print(f'Inference time: {end - start} seconds')
# Out:
# Inference time: 0.3231031894683838 seconds
# Inference time: 0.2662479877471924 seconds
# Inference time: 0.15711450576782227 seconds
# Inference time: 0.8332200050354004 seconds
# Inference time: 0.3084535598754883 seconds
# Inference time: 0.13425040245056152 seconds
